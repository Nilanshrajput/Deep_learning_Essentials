# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.0'

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#shape is attribute not method
iris.shape
# Out:
# (150, 5)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#pull rows and coulumn
spc=iris['species']
#or method2
spc=iris.species 
#this work only for single coulmn method 1 
#is more reliabe and general

# %%
#for multiple coulmns pass a list of names (python list is [])
iris[['species','petal_width']].head()
# Out:
#   species  petal_width
# 0  setosa          0.2
# 1  setosa          0.2
# 2  setosa          0.2
# 3  setosa          0.2
# 4  setosa          0.2

# %%
#print coulmn names
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
## Delete a coulmn
#M1- using python inbuilt del fn
del iris['species']
"""
del df.species 
this will not work better not to use this anytime
"""
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'species'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-8c93377655fc> in <module>
#       1 ## Delete a coulmn
#       2 #M1-
# ----> 3 del iris['species']
#       4 """
#       5 del df.species
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3515             # there was no match, this call should raise the appropriate
#    3516             # exception:
# -> 3517             self._data.delete(key)
#    3518
#    3519         # delete from the caches
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#     993         Delete selected item (items if non-unique) in-place.
#     994         """
# --> 995         indexer = self.items.get_loc(item)
#     996
#     997         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
# -> 2892                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2893         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2894         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'species'

# %%
 iris.drop( 'petal_width',axis=1, inplace=False)
    #axis to say we are droping the coulmn
    #id doesent remove coulmn from orginal dframe,
    #you can put inplace=true for 
    #droping coulmn from orginal dframe
# Out:
#      sepal_length  sepal_width  petal_length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %% [markdown]
# ## Subsetting row

# %%
# Loc 
#pull out rows
#row names as parameters
df.loc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.loc[-1] #doesnt work as we have no -1 labeled data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     375             try:
# --> 376                 return self._range.index(new_key)
#     377             except ValueError:
#
# ValueError: -1 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-5cf319cf20a3> in <module>
# ----> 1 df.loc[-1] #doesnt work as we have no -1 labeled data
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1408
#    1409             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1410             return self._getitem_axis(maybe_callable, axis=axis)
#    1411
#    1412     def _is_scalar_access(self, key: Tuple):
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1823         # fall thru to straight lookup
#    1824         self._validate_key(key, axis)
# -> 1825         return self._get_label(key, axis=axis)
#    1826
#    1827
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     155             raise IndexingError("no slices here, handle elsewhere")
#     156
# --> 157         return self.obj._xs(label, axis=axis)
#     158
#     159     def _get_loc(self, key: int, axis: int):
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3736             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3737         else:
# -> 3738             loc = self.index.get_loc(key)
#    3739
#    3740             if isinstance(loc, np.ndarray):
#
# D:\anaconda\envs\pytorch\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     376                 return self._range.index(new_key)
#     377             except ValueError:
# --> 378                 raise KeyError(key)
#     379         return super().get_loc(key, method=method, tolerance=tolerance)
#     380
#
# KeyError: -1

# %%
#in iloc it referes index of row
df.iloc[-1]
# Out:
# sepal_length          5.9
# sepal_width             3
# petal_length          5.1
# petal_width           1.8
# species         virginica
# Name: 149, dtype: object

# %%
df.ix[0]#will get depricated it looks for label name than index
# Out:
# D:\anaconda\envs\pytorch\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[[0,1,2]] #pass list of rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.loc[[0,1,2],['sepal_length','sepal_width']]
#thing on left od comma - how you subset the rows, 
#on right-how you subset coulmns
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
df.iloc[[0,1,2],[0,1]]# in iloc index goes
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2

# %%
sep_wid_mean=df['sepal_width'].mean()

# %%
sep_wid_mean
# Out:
# 3.0573333333333337

# %%
#boolean subsetting
df.loc[df['sepal_width']>sep_wid_mean,:]
# " : " for giving all coulmn or rows,
#in the case all coulmn as its in right of comma
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [67 rows x 5 columns]

# %% [markdown]
# # Groupby

# %%
df.groupby('species')

# %%
df.groupby('species')['sepal_width'].mean()
# Out:
# species
# setosa        3.428
# versicolor    2.770
# virginica     2.974
# Name: sepal_width, dtype: float64

# %%
df.groupby('species')[['sepal_width','sepal_length']].mean()
# Out:
#             sepal_width  sepal_length
# species
# setosa            3.428         5.006
# versicolor        2.770         5.936
# virginica         2.974         6.588

# %%
df.groupby(['species','petal_width'])[['sepal_width','sepal_length']].mean()
# Out:
#                         sepal_width  sepal_length
# species    petal_width
# setosa     0.1             3.360000      4.820000
#            0.2             3.379310      4.972414
#            0.3             3.328571      4.971429
#            0.4             3.785714      5.300000
#            0.5             3.300000      5.100000
#            0.6             3.500000      5.000000
# versicolor 1.0             2.371429      5.414286
#            1.1             2.466667      5.400000
#            1.2             2.740000      5.780000
#            1.3             2.746154      5.884615
#            1.4             2.957143      6.357143
#            1.5             2.880000      6.190000
#            1.6             3.133333      6.100000
#            1.7             3.000000      6.700000
#            1.8             3.200000      5.900000
# virginica  1.4             2.600000      6.100000
#            1.5             2.500000      6.150000
#            1.6             3.000000      7.200000
#            1.7             2.500000      4.900000
#            1.8             2.918182      6.445455
#            1.9             2.680000      6.340000
#            2.0             3.016667      6.650000
#            2.1             3.033333      6.916667
#            2.2             3.200000      6.866667
#            2.3             3.087500      6.912500
#            2.4             3.100000      6.266667
#            2.5             3.400000      6.733333
